# %% [markdown]
# # DSA Visualizer
# ---
# **Goal:** use matplotlib to create a visualizer for various data structures and algorithms.
#
# Note: I'm also building a visualizer using pygame.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import ipywidgets as wg

# %%
width = 300
height = 1

# %%
array = [1, 5, 7, 9, 10, 12, 13]
heights = [height] * len(array)
heights
# Out:
# [1, 1, 1, 1, 1, 1, 1]

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.animation as animation
fig, ax = plt.subplots()
ax.scatter([1,2, 1.5], [2, 1, 1.5])
cir = plt.Circle((1.5, 1.5), 0.07, color='r',fill=False)
ax.set_aspect('equal', adjustable='datalim')
ax.add_patch(cir)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,6))
p = plt.Circle((2,height), 1)
# ax.scatter(array, heights, s = 100, c = 'r', alpha = 0.5)
ax.add_patch(p)
ax.set_xlim([0,10])
ax.set_ylim([0,3])
# ax.axis('equal')
;
# Out:
# ''

# %% [markdown]
# - https://stackoverflow.com/questions/9230389/why-is-matplotlib-plotting-my-circles-as-ovals
